# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as mfm

import matplotlib

# %%
import pandas as pd

# %%
tst = pd.read_csv('/home/stedn/Desktop/global_income.csv',header=None,)
tst.columns = ['x','y']

# %%
tst.loc[tst['y']<1000,'y'] = 1000
tst['y'] = tst['y'].round(decimals=-3)
tst.loc[tst['y']>50000,'y'] = tst.loc[tst['y']>50000,'y'].round(decimals=-4)
r = (tst['y'])

theta = tst['x']/tst['x'].max()*np.pi*2
donut_inside = (10000)
donut_outside = (30000)
if False:
    r = np.log(r)
    donut_inside = np.log(donut_inside)
    donut_outside = np.log(donut_outside)
x = np.cos(theta)
y = np.sin(theta)
# r0 = r
# r = np.concatenate([r,r[::-1]])
# theta_1 = np.concatenate([theta,2*np.pi-theta[::-1]])
# x = np.concatenate([x,x[::-1]])
# y = np.concatenate([y,-y[::-1]])

# %%
plt.plot(tst['x'],tst['y'])
plt.plot([0,100],[10000,10000])
plt.plot([0,100],[30000,30000])
plt.yscale('log')
# Out:
# /home/stedn/anaconda3/envs/budget/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /home/stedn/anaconda3/envs/budget/lib/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /home/stedn/anaconda3/envs/budget/lib/python3.7/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
plt.plot(r*x,r*y)
plt.plot(donut_inside*x,donut_inside*y)
plt.plot(donut_outside*x,donut_outside*y)
# plt.xlim([-35000,35000])
# plt.ylim([-35000,35000])
plt.axes().axis('equal')
# Out:
# /home/stedn/anaconda3/envs/budget/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# (-81498.98444297377, 1051499.9516401417, -32999.82469200793, 32996.4956017564)

# %%
np.concatenate([-theta_1[:75:-1],theta_1[:75]])
# Out:
# array([-6.28318531, -6.27738304, -6.27158553, ...,  2.5136644 ,
#         2.53825774,  2.5680624 ])

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
plt.fill_between(theta, r)
plt.fill_between(theta[:75],r[:75])
ax.set_rmax(10000)
# ax.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
# ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
# ax.grid(True)

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
plt.fill_between(theta, r)
plt.fill_between(theta[425:475], r0[425:475])
ax.set_rmax(20000)
# ax.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
# ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
# ax.grid(True)

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
plt.fill_between(theta, r)
plt.plot(np.linspace(0,np.pi*2),np.ones(50)*10000,color='k')
plt.plot(np.linspace(0,np.pi*2),np.ones(50)*30000,color='k')
plt.fill_between(theta[500:870], r[500:870])
ax.set_rmax(40000)
# ax.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
# ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
# ax.grid(True)

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
plt.fill_between(theta, r)
plt.fill_between(theta[1300:], r0[1300:])
ax.set_rmax(100000)
# ax.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
# ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
# ax.grid(True)

# %%
dis = r.copy()
dis.loc[dis<10000] = 10000
dis.loc[(dis>10000) & (dis<30000)] = 30000
dis.loc[(dis>30000) & (dis<60000)] = 60000
dis.loc[(dis>60000)] = 1000000
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
plt.fill_between(theta, dis)
plt.fill_between(theta[:500], dis[:500])
plt.fill_between(theta[500:870], dis[500:870])
ax.set_rmax(100000)

# %%
dis = r.copy()
dis.loc[dis<10000] = 10000
dis.loc[(dis>10000) & (dis<30000)] = 30000
dis.loc[(dis>30000) & (dis<60000)] = 60000
dis.loc[(dis>60000)] = 1000000
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
plt.fill_between(theta, dis)
plt.fill_between(theta[:500], dis[:500])
plt.fill_between(theta[500:870], dis[500:870])
ax.set_rmax(200000)

# %%
dis = r.copy()
dis.loc[dis<10000] = 10000
dis.loc[(dis>10000) & (dis<30000)] = 30000
dis.loc[(dis>30000) & (dis<60000)] = 60000
dis.loc[(dis>60000)] = 1000000
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
plt.fill_between(theta, dis)
plt.fill_between(theta[:500], dis[:500])
plt.fill_between(theta[500:870], dis[500:870])
ax.set_rmax(300000)
